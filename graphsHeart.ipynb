# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Graping Accuracies for Logistic

regularization = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

'''
Logistic No Transform L1
validation_accuracy = [0.599733, 0.599733, 0.866933, 0.8992, 0.899467, 0.9, 0.900267, 0.900267, 0.900267]
training_accuracy = [0.59973,  0.59973,  0.876,    0.90187,  0.90187,  0.90427,  0.90427,  0.90453,  0.90453 ]
test_accuracy = [0.5712,   0.5712,   0.8808,   0.9064,   0.9064,   0.9096,   0.9096,   0.9096,   0.9096  ]
none_cv = 0.889467
none_train = 0.90453
none_test = 0.9096

Logistic No Transform L2
validation_accuracy = [ 0.841333, 0.8752, 0.8936, 0.8992, 0.899467, 0.9, 0.900267, 0.900267, 0.900267]
training_accuracy = [ 0.84293, 0.88107, 0.89707, 0.90267, 0.90267, 0.90453, 0.90453, 0.90453, 0.90453]
test_accuracy = [ 0.8336, 0.8752, 0.904, 0.9096, 0.9096, 0.9096, 0.9096, 0.9096, 0.9096]
none_cv = 0.899467
none_train = 0.90453
none_test = 0.9096

Logistic Degree 2 Transform L1
validation_accuracy = [0.599733,0.599733,0.869333,0.892,0.8848,0.8832,0.878667,0.879733,0.879733]
training_accuracy = [0.59973,0.59973,0.87413,0.8976,0.90107,0.90027,0.89813,0.8984,0.8984]
test_accuracy = [0.5712,0.5712,0.8784,0.8976,0.8904,0.8896,0.888,0.888,0.8888]
none_cv = 0.882933
none_train = 0.89947
none_test = 0.892

Logistic Degree 2 Transform L2
validation_accuracy = [0.8408, 0.866933, 0.8928, 0.8888, 0.882933, 0.883733, 0.880267, 0.8784, 0.877867]
training_accuracy = [0.84587, 0.8752, 0.90187, 0.90027, 0.89947, 0.8992, 0.89813, 0.8984, 0.89813]
test_accuracy = [0.8376, 0.8736, 0.9, 0.896, 0.892, 0.8904, 0.888, 0.8872, 0.8872]
none_cv = 0.882933
none_train = 0.89947
none_test = 0.892

Logistic Degree 3 Transform L1
validation_accuracy = [0.599733, 0.599733, 0.8624, 0.8888, 0.872, 0.838133, 0.819467, 0.814667, 0.8128]
training_accuracy = [0.59973, 0.83227, 0.86933, 0.9, 0.9128, 0.92693, 0.93413, 0.93413, 0.9336]
test_accuracy = [0.5712, 0.8352, 0.872, 0.896, 0.88, 0.8576, 0.8568, 0.8512, 0.8504]
none_cv = 0.864267
none_train = 0.91813
none_test = 0.8744

Logistic Degree 3 Transform L2
validation_accuracy = [0.855733, 0.879467, 0.885867, 0.877333, 0.864267, 0.841067, 0.8232, 0.815733, 0.796]
training_accuracy = [0.8624, 0.8928, 0.9056, 0.91013, 0.91813, 0.92667, 0.93333, 0.9368, 0.94053]
test_accuracy = [0.856, 0.8928, 0.8952, 0.8896, 0.8744, 0.8632, 0.856, 0.8408, 0.8304]
none_cv = 0.864267
none_train = 0.91813
none_test = 0.8744

Logistic Degree 4 Transform L1
validation_accuracy = [0.599733, 0.599733, 0.864267, 0.8864, 0.8408, 0.812533, 0.798667, 0.7992, 0.797067]
training_accuracy = [0.59973, 0.83227, 0.8736, 0.91013, 0.9408, 0.988, 0.99626, 0.9984, 0.9984]
test_accuracy = [0.5712, 0.8352, 0.8768, 0.9, 0.86, 0.828, 0.8168, 0.8296, 0.8296]
none_cv = 0.832267
none_train = 0.96853
none_test = 0.8472

Logistic Degree Transform L2'''
validation_accuracy = [0.87013, 0.88213, 0.87707, 0.8552, 0.83227, 0.81813, 0.80187, 0.79707, 0.79253]
training_accuracy = [0.88267, 0.9032, 0.9176, 0.9352, 0.96853, 0.988, 0.996, 0.9992, 0.9992]
test_accuracy = [0.88, 0.892, 0.892, 0.8656, 0.8472, 0.8272, 0.8192, 0.824, 0.8256]
none_cv = 0.832267
none_train = 0.96853
none_test = 0.8472





plt.axhline(none_test, color = 'yellow', linestyle='--', label='No Regularization Test Accuracy')
plt.axhline(none_cv, color = 'purple',linestyle='--', label='No Regularization Cross Validation Accuracy')
plt.axhline(none_train, color = 'red', linestyle='--', label='No Regularization Tain Accuracy')

plt.plot(regularization, training_accuracy, label='Training Accuracy')
plt.plot(regularization, test_accuracy, label='Test Accuracy')
plt.plot(regularization, validation_accuracy, label='Validation Accuracy')



plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')
plt.legend()
plt.show()

# %%
#Graping Accuracies for SVM

regularization = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

'''
SVM Linear Kernel

validation_accuracy = [0.59973, 0.86613, 0.86427, 0.88213, 0.88667, 0.88667, 0.88667, 0.88693, 0.88720]
training_accuracy = [0.59973, 0.88907, 0.87120, 0.88667, 0.88827, 0.88853, 0.88880, 0.88827, 0.89040]
test_accuracy = [0.57120, 0.88480, 0.87840, 0.89040, 0.89280, 0.89200, 0.89200, 0.89200, 0.89280]

SVM Polynomial Kernel
validation_accuracy = [0.59973, 0.59973, 0.59973, 0.80720, 0.88400, 0.86107, 0.81493, 0.78907, 0.78160]
training_accuracy = [0.59973, 0.59973, 0.61840, 0.85467, 0.90747, 0.92880, 0.94880, 0.95760, 0.96533]
test_accuracy = [0.57120, 0.57120, 0.59440, 0.82960, 0.89360, 0.88480, 0.84560, 0.81920, 0.79840]

SVM RBF Kernel
validation_accuracy = [0.59973, 0.59973, 0.59973, 0.86587, 0.88587, 0.87387, 0.83013, 0.81333, 0.80373]
training_accuracy = [0.59973, 0.59973, 0.62880, 0.87013, 0.91040, 0.95067, 0.99147, 0.99920, 1]
test_accuracy = [0.57120, 0.57120, 0.60320, 0.86640, 0.89520, 0.89440, 0.82960, 0.82480, 0.81760]

SVM Sigmoid Kernel'''
validation_accuracy = [0.59973, 0.59973, 0.77947, 0.85227, 0.82747, 0.80453, 0.79893, 0.80160, 0.79920]
training_accuracy = [0.59973, 0.59973, 0.81493, 0.84907, 0.80880, 0.78987, 0.79093, 0.79653, 0.79440]
test_accuracy = [0.57120, 0.57120, 0.80800, 0.85520, 0.79840, 0.77600, 0.77280, 0.79680, 0.77920]



plt.plot(regularization, training_accuracy, label='Training Accuracy')
plt.plot(regularization, test_accuracy, label='Test Accuracy')
plt.plot(regularization, validation_accuracy, label='Validation Accuracy')



plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')
plt.legend()
plt.show()

# %%
#Graping Accuracies for Neural Networks

regularization = [0, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

'''
NN Base
training_accuracy = [0.9136, 0.9128, 0.913, 0.913, 0.91, 0.907, 0.796, 0.5997, 0.5997, 0.5997]
test_accuracy = [0.9152, 0.9168, 0.9168, 0.9176, 0.9152, 0.9112, 0.7784, 0.5712, 0.5712, 0.5712]
validation_accuracy = [0.908,0.909,0.908,0.908,0.905,0.907,0.792,0.5997,0.5997,0.5997]

NN Base Plus
training_accuracy = [0.9168, 0.917, 0.917, 0.9168, 0.912, 0.907, 0.5997, 0.5997, 0.5997, 0.5997]
test_accuracy     = [0.9184, 0.9168, 0.9176, 0.9216, 0.9168, 0.912, 0.5712, 0.5712, 0.5712, 0.5712]
validation_accuracy = [0.911, 0.912, 0.912, 0.911, 0.909, 0.903, 0.5997, 0.5997, 0.5997, 0.5997]  

NN Wide
training_accuracy = [0.999, 0.9208, 0.9992, 0.9168, 0.9117, 0.9, 0.5997, 0.5997, 0.5997, 0.5997]
test_accuracy     = [0.8616, 0.9168, 0.8552, 0.9176, 0.9176, 0.9016, 0.5712, 0.5712, 0.5712, 0.5712]
validation_accuracy = [0.867, 0.869, 0.883, 0.912, 0.909, 0.901, 0.5997, 0.5997, 0.5997, 0.5997]

NN Deep'''
training_accuracy = [0.917, 0.935, 0.931, 0.916, 0.913, 0.5997, 0.5997, 0.5997, 0.5997, 0.5997]
test_accuracy     = [0.9176, 0.914, 0.9168, 0.9184, 0.9176, 0.5712, 0.5712, 0.5712, 0.5712, 0.5712]
validation_accuracy = [0.911, 0.912, 0.909, 0.913, 0.91, 0.5997, 0.5997, 0.5997, 0.5997, 0.5997] 


plt.plot(regularization, training_accuracy, label='Training Accuracy')
plt.plot(regularization, test_accuracy, label='Test Accuracy')
plt.plot(regularization, validation_accuracy, label='Validation Accuracy')



plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')
plt.legend()
plt.show()

# %%
#Neural Network Conclusion Graph

test_accuracy = [0.9184, 0.9168, 0.9176, 0.9216, 0.9168, 0.912, 0.5712, 0.5712, 0.5712, 0.571]
regularization = [0, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

plt.plot(regularization, test_accuracy, label='Test Accuracy')

index = regularization.index(0.01)
x, y = regularization[index], test_accuracy[index]

plt.scatter(x,y, color = 'red' ,label='Best Regularization')

plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')

plt.legend()
plt.show()

# %%
#SVM Conclusion Graph

test_accuracy = [0.5712,0.5712,0.6032,0.8664,0.8952,0.8944,0.8296,0.8248,0.8176]
regularization = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]


plt.plot(regularization, test_accuracy, label='Test Accuracy')

index = regularization.index(1)
x, y = regularization[index], test_accuracy[index]

plt.scatter(x,y, color = 'red' ,label='Best Regularization')

plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')

plt.legend()
plt.show()

# %%
#Logistic Conclusion Graph

test_accuracy = [0.5712,0.5712,0.8808,0.9064,0.9064,0.9096,0.9096,0.9096,0.9096]
regularization = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]

plt.plot(regularization, test_accuracy, label='Test Accuracy')
plt.axhline(0.9096, color='red', linestyle='--', label='No Regularization')


plt.xscale('log')
plt.xlabel('Regularization')
plt.ylabel('Score')
plt.title('Accuracy vs. Regularization')

plt.legend()
plt.show()
